# %% [markdown]
# # Обзор набора данных
# Этот ноутбук читает разметку и выводит краткую статистику.

# %%
import pandas as pd
labels = pd.read_csv('../dataset/annotations/video_labels.csv')
results = pd.read_csv('../dataset/annotations/program_results.csv')
labels.groupby(['exercise','quality_label']).size()

# %%
results[['filename','manual_quality','program_score','program_status','program_issues']]
